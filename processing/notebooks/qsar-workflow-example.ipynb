# %%
import os
import math
import numpy as np
import pandas as pd

# Import relevant modSAR classes 
from modSAR.network_algorithms import ModSAR
from modSAR.dataset import QSARDatasetIO
from modSAR.cdk_utils import CDKUtils
from modSAR.graph import GraphUtils
from scripts.validation import *

# %%
data_folder = '/mnt/data'
dataset_name = 'NYPR2'
filepath = os.path.join(data_folder, '%s.xlsx' % dataset_name)

qsar_dataset = QSARDatasetIO.load(filepath, dataset_name)
# Out:
# CDK Bridge process running
#  |████████████████████████████████████████████████████████████████████████████████████████████--------| 92.3%
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#  |█████████████████████████████████████████████████████████████████████████████████████████████████---| 97.1%
#  |██████████████████████████████████████████████████████████████████████████████████████████████████--| 98.3%
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# ...

# %%
import sys
sys.modules['scripts.validation']
# Out:
# <module 'scripts.validation' from '/mnt/code/scripts/validation.py'>

# %%
import sys
import importlib
importlib.reload(sys.modules['scripts.validation'])
importlib.reload(sys.modules['modSAR.network_algorithms'])
from modSAR.network_algorithms import ModSAR
from scripts.validation import *

# %%
data_split = DataSplit(qsar_dataset, filename='/mnt/data/NYPR2_splits.xlsx', n_splits=2)
modsar_obj = ModSAR()


qsar_validation = QSARValidation(estimator=modsar_obj, data_split=data_split, split_number=1)

# %%
param_grid = {'beta': [0.03], 'lam': [0.005, 0.05, 0.1], 'solver_name': ['cplex']}
fit_params = {'k': 0}

# %%
out = qsar_validation.predefined_cross_validation(param_grid, fit_params=fit_params, n_jobs=1)
# Out:
# ModSAR(beta=0.03, epsilon=0.01, lam=0.01, solver_name='cplex')
# Best Threshold = 0.25 | ACC = 0.694
# Iteration: 1/2
# QSARDataset NYPR2
#  -- Samples : 377
#  -- Features:  70
# (257, 70)
# ModSAR(beta=0.03, epsilon=0.01, lam=0.1, solver_name='cplex')
# Threshold: 0.25 | k: 0
# Num. samples in comm m23: 35
# OplraRegularised(beta=0.03, epsilon=0.01, exact_number_regions=None, lam=0.1,
#          solver_name='cplex')
# ########## R = 1
# SELECTED FEATURES:
# ['khs.ddssS']
#
# None
#
# OplraRegularised(beta=0.03, epsilon=0.01, exact_number_regions=None, lam=0.1,
#          solver_name='cplex')
# ########## R = 2 f* = khs.ddssS (loop 1/1) ###########
#
# OplraRegularised(beta=0.03, epsilon=0.01, exact_number_regions=None, lam=0.1,
#          solver_name='cplex')
# ########## R = 3 f* = khs.ddssS ###########
# Num. samples in comm m22: 43
# OplraRegularised(beta=0.03, epsilon=0.01, exact_number_regions=None, lam=0.1,
#          solver_name='cplex')
# ########## R = 1
# ...

# %%
results = out[0]
best_model = out[1]

# %%
best_model.fingerprints_training = None

# %%
from sklearn.externals import joblib
# joblib.dump(best_model, '/mnt/data/NYPR2_split01_modsar.joblib')

alg = joblib.load('/mnt/data/NYPR2_split01_modsar.joblib')

# %%
alg.predict(qsar_dataset.X.head(10), qsar_dataset.X_smiles.head(10))
# Out:
# array([ 5.98,  5.18,  5.09,  6.82,  6.82,  6.82,  6.82,  4.85,  5.18,  5.53])

# %%
qsar_dataset.y.head(10)
# Out:
#                pchembl_value
# CHEMBL1307319           5.11
# CHEMBL1308461           5.24
# CHEMBL1311570           5.09
# CHEMBL1311646           4.69
# CHEMBL1312220           5.35
# CHEMBL1312703           5.36
# CHEMBL1312713           5.16
# CHEMBL1327690           4.79
# CHEMBL1328939           5.18
# CHEMBL1329549           5.53

# %%
# %matplotlib inline
results['train_mae'].hist()

# %%
results['test_mae'].hist()

# %%
results['test_mae'].describe()
